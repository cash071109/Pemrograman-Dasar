# %% [markdown]
# <a href="https://colab.research.google.com/github/cash071109/Pemrograman-Dasar/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata Saya

nama = "Kasih Nuraini"
umur = 18
jurusan = "RPE"
semester = 3
matakuliah = "Pemograman Dasar"
status_lulus = False
nim = 4232501003
alamat = "Bengkong Laut"
kewarganegaraan = "Indonesia"
email = "kasihnuraini07@gmail.com"
hobi = "Hiking"
status = "Mahasiswa Aktif"

print (nama)
print (umur)
print (jurusan)
print (semester)
print (matakuliah)
print (status_lulus)
print (nim)
print (alamat)
print (kewarganegaraan)
print (email)
print (hobi)
print (status)
# Out:
# Kasih Nuraini
# 18
# RPE
# 3
# Pemograman Dasar
# False
# 4232501003
# Bengkong Laut
# Indonesia
# kasihnuraini07@gmail.com
# Hiking
# Mahasiswa Aktif
