# %% [markdown]
# <a href="https://colab.research.google.com/github/cash071109/Pemrograman-Dasar/blob/main/week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#latihan 1
tegangan_panel = 18
arus_panel = 6
jenis_sel = "Monocrystalline"
print (tegangan_panel)
print (arus_panel)
print (jenis_sel)
# Out:
# 18
# 6
# Monocrystalline

# %%
#Latihan 2
daya = 1500
frekuensi = 50.5
panel_aktif = False
jenis_generator = "AC"
print(daya, type(daya))
print(frekuensi, type(frekuensi))
print(panel_aktif, type(panel_aktif))
print(jenis_generator, type(jenis_generator))
# Out:
# 1500 <class 'int'>
# 50.5 <class 'float'>
# False <class 'bool'>
# AC <class 'str'>

# %%
#Latihan 3
nama_unit = "PLTS Nunukan"  #str
jumlah_panel = 240          #int
tegangan_keluar = 48.5      #float
sedang_beroperasi = True    #bool
print(nama_unit, type(nama_unit))
print(jumlah_panel, type(jumlah_panel))
print(tegangan_keluar, type(tegangan_keluar))
print(sedang_beroperasi, type(sedang_beroperasi))
# Out:
# PLTS Nunukan <class 'str'>
# 240 <class 'int'>
# 48.5 <class 'float'>
# True <class 'bool'>

# %%
#Latihan 4
tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]
print("Tegangan Harian:", tegangan_harian)
print("Pertama:", tegangan_harian[0])
print("Terakhir:", tegangan_harian[5])
tambah_tegangan_baru = tegangan_harian.append(220.0)
print("Jumlah Data:", len(tegangan_harian))
# Out:
# Tegangan Harian: [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]
# Pertama: 217.5
# Terakhir: 216.9
# Jumlah Data: 7

# %%
#Latihan 5
motor = {"nama" : "Yamaha", "daya_kW" : 5.5, "tegangan_V" : 380, "rpm" : 1500}
print(motor["nama"])
motor["rpm"] = 1750
print(motor)
# Out:
# Yamaha
# {'nama': 'Yamaha', 'daya_kW': 5.5, 'tegangan_V': 380, 'rpm': 1750}

# %%
#Latihan 6
pembangkit = [
{"PLTG": "Unit-1", "kapasitas_MW": 100, "status": "operasi"},
{"PLTA": "Unit-2", "kapasitas_MW": 150, "status": "operasi"},
{"PLTB": "Unit-3", "kapasitas_MW": 80,  "status": "pemeliharaan"},
]

print(pembangkit[1]["PLTA"])
pembangkit[2]["status"] = "terbengkalai"
pembangkit.append({"PLTU": "Unit-2", "kapasitas_MW": 130, "status": "operasi"})
print ("setelah data diperbarui")
for unit in pembangkit:
  print(unit)
# Out:
# Unit-2
# setelah data diperbarui
# {'PLTG': 'Unit-1', 'kapasitas_MW': 100, 'status': 'operasi'}
# {'PLTA': 'Unit-2', 'kapasitas_MW': 150, 'status': 'operasi'}
# {'PLTB': 'Unit-3', 'kapasitas_MW': 80, 'status': 'terbengkalai'}
# {'PLTU': 'Unit-2', 'kapasitas_MW': 130, 'status': 'operasi'}
